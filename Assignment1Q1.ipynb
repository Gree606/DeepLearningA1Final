# %%
#Question1
from matplotlib import pyplot
from keras.datasets import fashion_mnist
import wandb
import numpy as np
(trainX, trainY), (testX, testY) = fashion_mnist.load_data()
print('Train: X=%s, y=%s' % (trainX.shape, trainY.shape))
print('Test: X=%s, y=%s' % (testX.shape, testY.shape))
wandb.login()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)
# wandb: Currently logged in as: sleya7110. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(project='Assignment1Q1', entity='sleya7110')
# Out:
# ...
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/home/greeshma/Desktop/DeepLearning/wandb/run-20230315_191916-ojcx2wh0</code>
# Syncing run <strong><a href='https://wandb.ai/sleya7110/Assignment1Q1/runs/ojcx2wh0' target="_blank">dashing-dust-7</a></strong> to <a href='https://wandb.ai/sleya7110/Assignment1Q1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/sleya7110/Assignment1Q1' target="_blank">https://wandb.ai/sleya7110/Assignment1Q1</a>
#  View run at <a href='https://wandb.ai/sleya7110/Assignment1Q1/runs/ojcx2wh0' target="_blank">https://wandb.ai/sleya7110/Assignment1Q1/runs/ojcx2wh0</a>
# ...

# %%
#m_nist dataset has 10 classes
numClasses=10
fu=[]
for i in range(0,numClasses):
    #print('i=',i)
    for j in range(60000):
        if(trainY[j]==i):
            pyplot.subplot(4,3,i+1)
            pyplot.imshow(trainX[j], cmap=pyplot.get_cmap('gray'))
            # wandb.log({"ClassesImage": pyplot})
            fu.append(trainX[j])
            break
wandb.log({"ClassesImage": pyplot})
# fu=np.array(fu)
# wandb.log({"ClassesImage": [wandb.Image(fu,caption="hihi")]})
